# %% [markdown]
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fvalenzuelag/Ingenier-a-de-Soluciones-con-Inteligencia-Artificial/blob/main/RA1/IL1.2/1-zero-shot-prompting.ipynb)

# %% [markdown]
# # 1. Zero-Shot Prompting - Prompts Sin Ejemplos Previos
#
# ## Objetivos de Aprendizaje
# - Comprender los principios del zero-shot prompting
# - Diseñar prompts efectivos sin ejemplos previos
# - Aplicar técnicas de instrucción clara y contexto
# - Evaluar la efectividad de diferentes enfoques zero-shot
#
# ## ¿Qué es Zero-Shot Prompting?
#
# Zero-shot prompting es la técnica donde pedimos al modelo realizar una tarea **sin proporcionar ejemplos específicos** de cómo debe hacerla. El modelo debe basarse únicamente en:
# - Su entrenamiento previo
# - Las instrucciones que le damos
# - El contexto que proporcionamos
#
# ### Ventajas:
# - **Simplicidad**: No requiere crear ejemplos
# - **Flexibilidad**: Fácil de adaptar a nuevas tareas
# - **Eficiencia**: Menos tokens utilizados
# - **Generalización**: Funciona para tareas diversas
#
# ### Limitaciones:
# - **Inconsistencia**: Resultados pueden variar más
# - **Formato**: Menos control sobre la estructura de salida
# - **Tareas complejas**: Puede requerir instrucciones muy detalladas
# - **Dominio específico**: Menos efectivo en nichos especializados

# %%
# --- Instalación de dependencias (se ejecuta solo en Google Colab) ---
# En local no hace nada: usa `pip install -r requirements.txt` desde la raíz del repo.
import sys
if "google.colab" in sys.modules:
    # !pip install -q langchain langchain-classic langchain-openai python-dotenv

# %%
# --- Credenciales: funciona en local (.env) y en Google Colab (Secrets) ---
import os
try:
    from google.colab import userdata          # Colab: panel 🔑 Secrets
    # Solo LLM_API_KEY es obligatorio. Los demás son opcionales: defínelos como
    # Secrets únicamente si quieres usar otro proveedor o modelo.
    for _k in ("LLM_API_KEY", "GOOGLE_API_KEY", "LANGSMITH_API_KEY",
               "LLM_BASE_URL", "LLM_MODEL", "LLM_MODEL_SMALL"):
        try:
            os.environ[_k] = userdata.get(_k)
        except Exception:
            pass                                # el Secret no existe: se usa el default
    os.environ.setdefault("LLM_BASE_URL", "https://api.groq.com/openai/v1")
    os.environ.setdefault("LLM_MODEL", "llama-3.3-70b-versatile")
    os.environ.setdefault("LLM_MODEL_SMALL", "llama-3.1-8b-instant")
except ImportError:
    from dotenv import load_dotenv             # Local: archivo .env en la raíz
    load_dotenv()

# Configuración inicial
from langchain_openai import ChatOpenAI
# LangChain v1: langchain_core.messages / langchain_core.documents
from langchain_classic.schema import HumanMessage, SystemMessage
import os
import time

# Configurar el modelo
llm = ChatOpenAI(
    base_url=os.getenv("LLM_BASE_URL"),
    api_key=os.getenv("LLM_API_KEY"),
    model=os.getenv("LLM_MODEL", "llama-3.3-70b-versatile"),
    temperature=0.7  # Balance entre creatividad y consistencia
)

print("✓ Modelo configurado para zero-shot prompting")
# Out:
# ✓ Modelo configurado para zero-shot prompting

# %% [markdown]
# ## Anatomía de un Prompt Zero-Shot Efectivo
#
# Un prompt zero-shot efectivo tiene estos componentes:
#
# 1. **Contexto/Rol**: Quién debe "ser" el modelo
# 2. **Tarea**: Qué debe hacer específicamente
# 3. **Formato**: Cómo debe estructurar la respuesta
# 4. **Restricciones**: Qué debe evitar o considerar
# 5. **Input**: Los datos específicos a procesar

# %%
# Ejemplo básico vs mejorado
def comparar_prompts_basico():
    texto = "El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy alto."
    
    # Prompt básico (menos efectivo)
    prompt_basico = f"Analiza este texto: {texto}"
    
    # Prompt mejorado (más efectivo)
    prompt_mejorado = f"""Eres un analista de sentimientos experto. 
    
Tarea: Analiza el sentimiento del siguiente texto sobre un producto.
    
Formato de respuesta:
- Sentimiento general: [Positivo/Negativo/Neutral]
- Aspectos positivos: [lista]
- Aspectos negativos: [lista]
- Puntuación de confianza: [0-10]
    
Texto a analizar: "{texto}"""
    
    print("=== COMPARACIÓN DE PROMPTS ===")
    
    # Probar prompt básico
    print("\n1. PROMPT BÁSICO:")
    print(f"Prompt: {prompt_basico}")
    try:
        response1 = llm.invoke([HumanMessage(content=prompt_basico)])
        print(f"Respuesta: {response1.content}")
    except Exception as e:
        print(f"Error: {e}")
    
    print("\n" + "-"*60)
    
    # Probar prompt mejorado
    print("\n2. PROMPT MEJORADO:")
    print(f"Prompt: {prompt_mejorado[:100]}...")
    try:
        response2 = llm.invoke([HumanMessage(content=prompt_mejorado)])
        print(f"Respuesta: {response2.content}")
    except Exception as e:
        print(f"Error: {e}")
    
    print("\n=== ANÁLISIS ===")
    print("• Prompt básico: Ambiguo, respuesta poco estructurada")
    print("• Prompt mejorado: Específico, respuesta estructurada y útil")

# Ejecutar comparación
comparar_prompts_basico()
# Out:
# === COMPARACIÓN DE PROMPTS ===
#
# 1. PROMPT BÁSICO:
# Prompt: Analiza este texto: El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy alto.
# Respuesta: Análisis del texto:
#
# **Contenido**:
# El texto habla sobre el nuevo iPhone, destacando dos de sus características: la batería y la cámara. La batería se describe como "increíble" y la cámara como "fantástica". Sin embargo, también se menciona que el precio del iPhone es "muy alto".
#
# **Tono**:
# El tono del texto es neutro, ya que presenta tanto aspectos positivos (batería y cámara) como negativos (precio) del producto. No hay un enfoque emocional ni persuasivo claro.
#
# **Estructura**:
# La oración tiene una estructura simple y clara, con tres partes:
#
# 1. Presentación de la característica positiva 1 (batería increíble)
# 2. Presentación de la característica positiva 2 (cámara fantástica)
# 3. Presentación de la característica negativa (precio muy alto)
#
# **Léxico**:
# El vocabulario utilizado es común y accesible. Las palabras "increíble" y "fantástica" tienen un matiz positivo, mientras que "muy alto" tiene un matiz negativo.
#
# **Propósito**:
# El propósito del texto parece ser informar o comentar sobre el nuevo iPhone, destacando sus características y precio. No hay un objetivo claro de persuadir o convencer al lector de comprar o no el producto.
#
# En resumen, el texto es una descripción objetiva del nuevo iPhone, destacando tanto sus ventajas como sus desventajas.
#
# ------------------------------------------------------------
#
# 2. PROMPT MEJORADO:
# Prompt: Eres un analista de sentimientos experto.
#
# Tarea: Analiza el sentimiento del siguiente texto sobre ...
# Respuesta: - Sentimiento general: Neutral
# - Aspectos positivos:
#   * La batería es increíble
#   * La cámara es fantástica
# - Aspectos negativos:
#   * El precio es muy alto
# - Puntuación de confianza: 8
#
# Análisis detallado: El texto presenta una evaluación mixta del nuevo iPhone. Por un lado, se destacan aspectos positivos como la batería y la cámara, lo que sugiere que el producto tiene características técnicas destacadas. Sin embargo, el precio alto es un punto negativo significativo que podría influir en la decisión de compra de los consumidores. Debido a esta evaluación mixta, el sentimiento general se considera neutral. La puntuación de confianza es de 8 porque el lenguaje utilizado es claro y directo, lo que indica una opinión honesta y bien fundamentada.
#
# === ANÁLISIS ===
# • Prompt básico: Ambiguo, respuesta poco estructurada
# • Prompt mejorado: Específico, respuesta estructurada y útil

# %% [markdown]
# ## Técnicas de Zero-Shot por Tipo de Tarea
#
# Diferentes tipos de tareas requieren enfoques específicos en zero-shot prompting.

# %%
# 1. CLASIFICACIÓN
def zero_shot_clasificacion():
    print("=== ZERO-SHOT PARA CLASIFICACIÓN ===")
    
    emails = [
        "Reunión de equipo mañana a las 10 AM en sala de conferencias",
        "¡Felicidades! Has ganado $1,000,000! Haz clic aquí ahora",
        "Recordatorio: Tu factura de internet vence en 3 días"
    ]
    
    # Prompt optimizado para clasificación
    clasificacion_prompt = """Eres un clasificador de emails empresariales.
    
Clasifica cada email en una de estas categorías:
- TRABAJO: Relacionado con tareas laborales
- SPAM: Contenido no solicitado o sospechoso
- PERSONAL: Asuntos personales o administrativos

Responde solo con el nombre de la categoría.

Email: "{}"
Categoría:"""
    
    for i, email in enumerate(emails, 1):
        prompt = clasificacion_prompt.format(email)
        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            print(f"{i}. Email: {email[:50]}...")
            print(f"   Clasificación: {response.content.strip()}\n")
        except Exception as e:
            print(f"Error en email {i}: {e}")

# Ejecutar clasificación
zero_shot_clasificacion()
# Out:
# === ZERO-SHOT PARA CLASIFICACIÓN ===
# 1. Email: Reunión de equipo mañana a las 10 AM en sala de co...
#    Clasificación: TRABAJO
# 2. Email: ¡Felicidades! Has ganado $1,000,000! Haz clic aquí...
#    Clasificación: SPAM
# 3. Email: Recordatorio: Tu factura de internet vence en 3 dí...
#    Clasificación: PERSONAL

# %%
# 2. GENERACIÓN DE CONTENIDO
def zero_shot_generacion():
    print("=== ZERO-SHOT PARA GENERACIÓN ===")
    
    # Prompt estructurado para generación
    generacion_prompt = """Eres un copywriter creativo especializado en redes sociales.
    
Tarea: Crear un post para LinkedIn sobre el tema dado.
    
Requisitos:
- Tono profesional pero accesible
- Máximo 150 palabras
- Incluir 1-2 hashtags relevantes
- Hacer una pregunta para fomentar engagement
    
Tema: "Importancia del aprendizaje continuo en tecnología"
    
Post para LinkedIn:"""
    
    try:
        response = llm.invoke([HumanMessage(content=generacion_prompt)])
        print("Post generado:")
        print("-" * 40)
        print(response.content)
        print("-" * 40)
        
        # Análisis del resultado
        words = len(response.content.split())
        hashtags = response.content.count('#')
        questions = response.content.count('?')
        
        print(f"\nAnálisis:")
        print(f"• Palabras: {words} (límite: 150)")
        print(f"• Hashtags: {hashtags}")
        print(f"• Preguntas: {questions}")
        print(f"• Cumple requisitos: {'✓' if words <= 150 and hashtags >= 1 and questions >= 1 else '✗'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar generación
zero_shot_generacion()
# Out:
# === ZERO-SHOT PARA GENERACIÓN ===
# Post generado:
# ----------------------------------------
# En el mundo de la tecnología, el cambio es constante y la innovación es rápida. Para mantenerse relevante, es fundamental priorizar el aprendizaje continuo. ¿Qué habilidades o tecnologías nuevas estás explorando actualmente para mejorar tus compétencias profesionales?
#
# El aprendizaje continuo no solo nos permite estar al día con las últimas tendencias, sino que también nos abre puertas a nuevas oportunidades y desafíos. Invertir en nuestra educación y desarrollo es invertir en nuestro futuro.
#
# Comparte con nosotros tus experiencias y consejos sobre cómo mantener un ritmo de aprendizaje constante en la industria tecnológica. #AprendizajeContinuo #Tecnología
# ----------------------------------------
#
# Análisis:
# • Palabras: 94 (límite: 150)
# • Hashtags: 2
# • Preguntas: 1
# • Cumple requisitos: ✓

# %%
# 3. EXTRACCIÓN DE INFORMACIÓN
def zero_shot_extraccion():
    print("=== ZERO-SHOT PARA EXTRACCIÓN ===")
    
    # Texto de ejemplo
    texto_noticia = """Apple Inc. anunció hoy que su CEO Tim Cook se reunirá con inversores 
    el próximo 15 de marzo de 2024 en Cupertino, California. La reunión abordará los 
    resultados financieros del Q1 2024, donde la compañía reportó ingresos de $89.5 
    billones. Cook también discutirá la nueva estrategia de IA de Apple y el lanzamiento 
    del iPhone 16 programado para septiembre. Las acciones de Apple (AAPL) subieron 
    3.2% tras el anuncio."""
    
    # Prompt para extracción estructurada
    extraccion_prompt = f"""Eres un analista financiero experto en extraer datos clave.
    
Extrae la siguiente información del texto dado:
    
Formato de respuesta (JSON):
{{
  "empresa": "nombre de la empresa",
  "ceo": "nombre del CEO",
  "fecha_evento": "fecha del evento",
  "ubicacion": "ubicación del evento",
  "ingresos": "cifra de ingresos mencionada",
  "productos": ["lista de productos mencionados"],
  "cambio_acciones": "porcentaje de cambio en acciones"
}}
    
Texto: "{texto_noticia}"
    
JSON:"""
    
    try:
        response = llm.invoke([HumanMessage(content=extraccion_prompt)])
        print("Información extraída:")
        print(response.content)
        
        # Intentar parsear como JSON para validar formato
        import json
        try:
            data = json.loads(response.content)
            print("\n✓ Formato JSON válido")
            print(f"✓ Campos extraídos: {len(data)} elementos")
        except:
            print("\n✗ Formato JSON inválido - necesita refinamiento del prompt")
            
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar extracción
zero_shot_extraccion()
# Out:
# === ZERO-SHOT PARA EXTRACCIÓN ===
# Información extraída:
# Aquí te dejo la información extraída en formato JSON:
#
# ```
# {
#   "empresa": "Apple Inc.",
#   "ceo": "Tim Cook",
#   "fecha_evento": "15 de marzo de 2024",
#   "ubicacion": "Cupertino, California",
#   "ingresos": "$89.5 billones",
#   "productos": ["iPhone 16"],
#   "cambio_acciones": "3.2%"
# }
# ```
#
# ✗ Formato JSON inválido - necesita refinamiento del prompt

# %% [markdown]
# ## Optimización de Prompts Zero-Shot
#
# Técnicas para mejorar la efectividad de prompts zero-shot.

# %%
# Técnica 1: Prompts con Roles Específicos
def roles_especificos():
    print("=== OPTIMIZACIÓN: ROLES ESPECÍFICOS ===")
    
    pregunta = "¿Cómo puedo mejorar el rendimiento de mi aplicación web?"
    
    roles = {
        "Genérico": "Responde la siguiente pregunta:",
        "Desarrollador Senior": "Eres un desarrollador senior con 10 años de experiencia en optimización web. Responde como un experto:",
        "Consultor de Performance": "Eres un consultor especializado en performance web que ha optimizado cientos de aplicaciones. Proporciona una respuesta detallada y técnica:",
        "CTO": "Eres un CTO de una startup tecnológica. Responde con una perspectiva estratégica y técnica balanceada:"
    }
    
    for rol, contexto in roles.items():
        prompt = f"{contexto}\n\n{pregunta}"
        
        print(f"\n{rol.upper()}:")
        print("-" * 30)
        
        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            # Mostrar solo las primeras líneas para comparación
            preview = response.content[:200] + "..." if len(response.content) > 200 else response.content
            print(preview)
        except Exception as e:
            print(f"Error: {e}")
    
    print("\n=== OBSERVACIONES ===")
    print("• Roles específicos generan respuestas más enfocadas")
    print("• La experticia del rol influye en la profundidad técnica")
    print("• El contexto profesional afecta el tipo de soluciones propuestas")

# Ejecutar ejemplo de roles
roles_especificos()
# Out:
# === OPTIMIZACIÓN: ROLES ESPECÍFICOS ===
#
# GENÉRICO:
# ------------------------------
# Existen varias formas de mejorar el rendimiento de una aplicación web, aquí te presento algunas sugerencias:
#
# 1. **Optimiza el código**: Asegúrate de que tu código sea eficiente y no contenga errores....
#
# DESARROLLADOR SENIOR:
# ------------------------------
# Excelente pregunta! La optimización del rendimiento de una aplicación web es un tema muy importante, ya que puede afectar directamente la experiencia del usuario y, en última instancia, el éxito de tu...
#
# CONSULTOR DE PERFORMANCE:
# ------------------------------
# **Mejora del Rendimiento de Aplicaciones Web: Un Enfoque Integral**
#
# La mejora del rendimiento de una aplicación web es un proceso complejo que requiere considerar múltiples factores, desde la arquite...
#
# CTO:
# ------------------------------
# Excelente pregunta! Como CTO de una startup tecnológica, puedo decirte que mejorar el rendimiento de una aplicación web es un proceso continuo que requiere una combinación de estrategias técnicas y de...
#
# === OBSERVACIONES ===
# • Roles específicos generan respuestas más enfocadas
# • La experticia del rol influye en la profundidad técnica
# • El contexto profesional afecta el tipo de soluciones propuestas

# %%
# Técnica 2: Instrucciones Graduales
def instrucciones_graduales():
    print("=== OPTIMIZACIÓN: INSTRUCCIONES GRADUALES ===")
    
    # Problema complejo para demostrar
    problema = "Necesito crear una estrategia de marketing digital para lanzar una nueva app de fitness"
    
    # Prompt con instrucciones graduales
    prompt_gradual = f"""Eres un estratega de marketing digital senior.
    
Problema: {problema}
    
Desarrolla una estrategia siguiendo este proceso paso a paso:
    
PASO 1: Análisis inicial
- Identifica el público objetivo
- Define 3 puntos de valor únicos de la app
    
PASO 2: Canales de marketing
- Selecciona 4-5 canales digitales más efectivos
- Justifica cada selección
    
PASO 3: Estrategia de contenido
- Define tipos de contenido para cada canal
- Sugiere frecuencia de publicación
    
PASO 4: Métricas y KPIs
- Define 5 métricas clave para medir éxito
- Sugiere herramientas de medición
    
Desarrolla cada paso con detalle:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_gradual)])
        print("ESTRATEGIA DESARROLLADA:")
        print("=" * 50)
        print(response.content)
        
        # Análisis de estructura
        pasos_detectados = response.content.count("PASO")
        secciones = ["análisis", "canales", "contenido", "métricas"]
        secciones_encontradas = sum(1 for seccion in secciones if seccion.lower() in response.content.lower())
        
        print("\n=== ANÁLISIS DE ESTRUCTURA ===")
        print(f"• Pasos identificados: {pasos_detectados}/4")
        print(f"• Secciones cubiertas: {secciones_encontradas}/4")
        print(f"• Estructura seguida: {'✓' if pasos_detectados >= 3 else '✗'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar instrucciones graduales
instrucciones_graduales()
# Out:
# === OPTIMIZACIÓN: INSTRUCCIONES GRADUALES ===
# ESTRATEGIA DESARROLLADA:
# ==================================================
# **PASO 1: Análisis inicial**
#
# En este paso, nos enfocamos en entender quién es nuestro público objetivo y qué aspectos únicos de nuestra app de fitness los atraerá.
#
# * **Identifica el público objetivo**: Nuestro público objetivo son personas entre 25 y 45 años, interesadas en mejorar su condición física y llevar un estilo de vida saludable. Estas personas probablemente tienen un nivel de ingresos medio a alto, están activas en redes sociales y buscan soluciones digitales para su bienestar. Dentro de este grupo, podemos identificar subgrupos como:
#  + Principiantes en el ejercicio que buscan rutinas fáciles de seguir.
#  + Atletas experimentados que buscan desafíos y seguimiento detallado de su progreso.
#  + Personas con objetivos específicos de pérdida de peso o ganancia de masa muscular.
# * **Define 3 puntos de valor únicos de la app**:
#  1. **Personalización**: Nuestra app ofrece planes de entrenamiento personalizados basados en los objetivos, nivel de condición física y preferencias del usuario. Esto se logra a través de un algoritmo avanzado que analiza los datos del usuario y ajusta el plan de entrenamiento en tiempo real.
#  2. **Comunidad**: La app incluye una comunidad activa donde los usuarios pueden conectarse con otros que tienen objetivos similares, compartir progreso, y obtener apoyo y motivación. Esto incluye foros, grupos de desafíos y eventos en vivo.
#  3. **Integración con dispositivos de seguimiento de actividad**: Nuestra app se integra sin problemas con los dispositivos de seguimiento de actividad más populares, permitiendo a los usuarios sincronizar sus datos de actividad física y obtener una visión más completa de su progreso y salud.
#
# **PASO 2: Canales de marketing**
#
# En este paso, seleccionamos los canales digitales más efectivos para alcanzar a nuestro público objetivo y promocionar nuestra app.
#
# * **Selecciona 4-5 canales digitales más efectivos**:
#  1. **Instagram**: Debido a su enfoque visual y la gran cantidad de usuarios que comparten contenido relacionado con el fitness y el estilo de vida saludable.
#  2. **Facebook**: Por su alcance masivo y la capacidad de crear anuncios dirigidos a audiencias específicas.
#  3. **Influencers de Fitness**: Colaborar con influencers en el nicho de fitness para promocionar la app a sus seguidores.
#  4. **YouTube**: Crear un canal de YouTube con tutoriales de ejercicios, testimonios de usuarios y contenido educativo sobre fitness y nutrición.
#  5. **Instagram Reels y TikTok**: Utilizar estos formatos cortos para compartir consejos de fitness, prévias de entrenamientos y promociones especiales.
# * **Justifica cada selección**: Cada uno de estos canales ofrece una forma única de conectarse con nuestro público objetivo. Instagram y Facebook permiten una gran segmentación y personalización de los anuncios. Los influencers de fitness pueden ofrecer recomendaciones auténticas y alcanzar a audiencias muy específicas. YouTube permite crear contenido más profundo y educativo, mientras que Instagram Reels y TikTok son ideales para contenido más ligero y viral.
#
# **PASO 3: Estrategia de contenido**
#
# En este paso, definimos los tipos de contenido que crearemos para cada canal y sugerimos una frecuencia de publicación.
#
# * **Define tipos de contenido para cada canal**:
#  + **Instagram**: Imágenes y videos de entrenamientos, consejos de nutrición, historias de éxito de usuarios, y promociones especiales.
#  + **Facebook**: Anuncios dirigidos, eventos en vivo, grupos de discusión sobre fitness y salud, y contenido educativo.
#  + **Influencers de Fitness**: Colaboraciones para promocionar la app, compartir experiencias personales y ofrecer descuentos exclusivos.
#  + **YouTube**: Tutoriales de ejercicios, videos explicativos sobre técnicas de entrenamiento, entrevistas con expertos en fitness y testimonios de usuarios.
#  + **Instagram Reels y TikTok**: Clips cortos de entrenamientos, consejos rápidos de fitness, y desafíos virales.
# * **Sugiere frecuencia de publicación**:
#  + **Instagram**: 3-4 publicaciones por semana, incluyendo al menos un video o historia por semana.
#  + **Facebook**: 2-3 publicaciones por semana, con un enfoque en anuncios dirigidos y contenido interactivo.
#  + **Influencers de Fitness**: Colaboraciones mensuales, con al menos 2 publicaciones por colaboración.
#  + **YouTube**: 1-2 videos por semana, dependiendo de la complejidad del contenido.
#  + **Instagram Reels y TikTok**: 5-7 publicaciones por semana, aprovechando la naturaleza viral de estos formatos.
#
# **PASO 4: Métricas y KPIs**
#
# En este paso, definimos las métricas clave para medir el éxito de nuestra estrategia de marketing y sugerimos herramientas para medirlas.
#
# * **Define 5 métricas clave para medir éxito**:
#  1. **Tasa de descarga de la app**: El número de descargas directas desde la tienda de aplicaciones.
#  2. **Tasa de retención de usuarios**: La proporción de usuarios que siguen utilizando la app después de un período determinado.
#  3. **Engagement en redes sociales**: La cantidad de interacciones (me gustas, comentarios, compartidos) en cada plataforma.
#  4. **Conversión de leads**: La proporción de usuarios que se convierten en usuarios registrados o pagan por suscripciones premium.
#  5. **Valor de vida del cliente (CLV)**: El valor total que un usuario aporta a la app a lo largo de su vida como cliente.
# * **Sugiere herramientas de medición**:
#  + **Google Analytics**: Para medir tráfico web y conversión de leads.
#  + **Herramientas de análisis de redes sociales**: Como Hootsuite Insights o Sprout Social para medir el engagement.
#  + **Herramientas de seguimiento de aplicaciones**: Como App Annie o Flurry para monitorear descargas y retención de usuarios.
#  + **CRM (Customer Relationship Management)**: Para gestionar y analizar la interacción con los clientes y calcular el CLV.
#  + **Herramientas de seguimiento de marketing**: Como Mailchimp o Marketo para medir el éxito de campañas de email marketing y otros esfuerzos de marketing.
#
# Al seguir estos pasos, podemos desarrollar una estrategia de marketing digital sólida para nuestra app de fitness, asegurando que estamos dirigidos a nuestro público objetivo de la manera más efectiva posible y midiendo continuamente nuestro éxito para ajustar y mejorar nuestra estrategia.
#
# === ANÁLISIS DE ESTRUCTURA ===
# • Pasos identificados: 4/4
# • Secciones cubiertas: 4/4
# • Estructura seguida: ✓

# %% [markdown]
# ## Casos de Uso Avanzados
#
# Aplicaciones más sofisticadas de zero-shot prompting.

# %%
# Caso de uso: Análisis de código
def analisis_codigo_zero_shot():
    print("=== CASO DE USO: ANÁLISIS DE CÓDIGO ===")
    
    codigo_ejemplo = '''def process_user_data(users):
    result = []
    for user in users:
        if user["age"] > 18:
            result.append({
                "name": user["name"].upper(),
                "email": user["email"],
                "status": "adult"
            })
    return result'''
    
    prompt_analisis = f"""Eres un senior code reviewer con experiencia en Python.
    
Analiza el siguiente código y proporciona:
    
1. FUNCIONALIDAD:
   - ¿Qué hace este código?
   - ¿Cuál es su propósito?
    
2. PROBLEMAS POTENCIALES:
   - Errores de lógica
   - Vulnerabilidades de seguridad
   - Problemas de rendimiento
    
3. MEJORAS SUGERIDAS:
   - Optimizaciones de código
   - Mejores prácticas
   - Manejo de errores
    
4. PUNTUACIÓN DE CALIDAD: [1-10]
    
Código a analizar:
```python
{codigo_ejemplo}
```
    
Análisis:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_analisis)])
        print("ANÁLISIS DE CÓDIGO:")
        print("=" * 50)
        print(response.content)
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar análisis de código
analisis_codigo_zero_shot()
# Out:
# === CASO DE USO: ANÁLISIS DE CÓDIGO ===
# ANÁLISIS DE CÓDIGO:
# ==================================================
# **Análisis del Código**
#
# ### 1. FUNCIONALIDAD
#
# * **Qué hace este código:** El código define una función llamada `process_user_data` que toma una lista de diccionarios (`users`) como entrada. Cada diccionario representa un usuario y contiene al menos tres claves: `"name"`, `"email"` y `"age"`. La función itera sobre la lista de usuarios y, para cada usuario con una edad mayor a 18, crea un nuevo diccionario con el nombre en mayúsculas, el correo electrónico tal como está, y un estado (`"status"`) establecido en `"adult"`. Estos nuevos diccionarios son agregados a una lista (`result`) que se devuelve al final.
# * **Cuál es su propósito:** El propósito de este código es filtrar y transformar datos de usuarios, específicamente identificar a los usuarios adultos (mayores de 18 años) y devolver sus datos en un formato específico.
#
# ### 2. PROBLEMAS POTENCIALES
#
# * **Errores de lógica:**
#  + La función asume que todos los diccionarios en la lista `users` tienen las claves `"name"`, `"email"` y `"age"`. Si algún diccionario falta alguna de estas claves, el código fallará con un `KeyError`.
#  + La función no maneja el caso en el que `"age"` no sea un número. Si `"age"` es una cadena o un valor de otro tipo que no se puede comparar con 18, el código puede fallar o producir resultados inesperados.
# * **Vulnerabilidades de seguridad:**
#  + No se identifican vulnerabilidades de seguridad directas en este código, ya que no interactúa con sistemas externos ni maneja datos sensibles de manera insegura. Sin embargo, la falta de validación de la entrada podría potencialmente ser explotada si el código se integra en un sistema más amplio que maneja datos sensibles.
# * **Problemas de rendimiento:**
#  + El código tiene una complejidad temporal de O(n), donde n es el número de usuarios, ya que itera sobre la lista de usuarios una vez. Esto es aceptable para la mayoría de los casos, a menos que la lista de usuarios sea extremadamente grande, en cuyo caso podría haber preocupaciones de rendimiento.
#
# ### 3. MEJORAS SUGERIDAS
#
# * **Optimizaciones de código:**
#  + Utilizar comprensión de listas puede hacer el código más conciso y potencialmente más rápido.
#  + Agregar validación para asegurarse de que cada diccionario de usuario contiene las claves esperadas y que `"age"` es un número.
# * **Mejores prácticas:**
#  + Utilizar tipos hinting para la función para indicar el tipo de datos que se espera y se devuelve.
#  + Considerar el uso de una clase `Usuario` en lugar de diccionarios para representar a los usuarios, especialmente si se van a agregar más métodos o validaciones relacionadas con los usuarios.
# * **Manejo de errores:**
#  + Agregar bloques `try-except` para manejar posibles errores, como `KeyError` o `TypeError`, y proporcionar mensajes de error útiles.
#
# ### 4. PUNTUACIÓN DE CALIDAD: 6
#
# El código es claro y simple, pero carece de validación de entrada y manejo de errores, lo que podría llevar a problemas si se utiliza en un contexto más amplio. Con algunas mejoras en estas áreas, el código podría ser más robusto y confiable.

# %%
# Caso de uso: Generación de tests
def generacion_tests_zero_shot():
    print("=== CASO DE USO: GENERACIÓN DE TESTS ===")
    
    funcion_a_testear = '''def calculate_discount(price, discount_percent, user_type):
    """Calculate final price after discount.
    
    Args:
        price (float): Original price
        discount_percent (float): Discount percentage (0-100)
        user_type (str): 'premium' or 'regular'
        
    Returns:
        float: Final price after discount
    """
    if user_type == 'premium':
        discount_percent += 5  # Extra 5% for premium users
    
    discount_amount = price * (discount_percent / 100)
    return price - discount_amount'''
    
    prompt_tests = f"""Eres un QA engineer experto en testing de Python.
    
Genera tests unitarios completos para la siguiente función usando pytest.
    
Incluye tests para:
1. Casos normales (diferentes tipos de usuario y descuentos)
2. Casos edge (descuento 0%, 100%, valores negativos)
3. Casos de error (tipos incorrectos, valores inválidos)
4. Tests parametrizados cuando sea apropiado
    
Función a testear:
```python
{funcion_a_testear}
```
    
Genera código de test completo y ejecutable:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_tests)])
        print("TESTS GENERADOS:")
        print("=" * 50)
        print(response.content)
        
        # Análisis básico de los tests generados
        test_methods = response.content.count("def test_")
        assertions = response.content.count("assert")
        parametrize = response.content.count("@pytest.mark.parametrize")
        
        print("\n=== ANÁLISIS DE TESTS ===")
        print(f"• Métodos de test: {test_methods}")
        print(f"• Assertions: {assertions}")
        print(f"• Tests parametrizados: {parametrize}")
        print(f"• Cobertura estimada: {'Alta' if test_methods >= 5 else 'Media' if test_methods >= 3 else 'Baja'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar generación de tests
generacion_tests_zero_shot()
# Out:
# === CASO DE USO: GENERACIÓN DE TESTS ===
# TESTS GENERADOS:
# ==================================================
# ```python
# # tests/test_calculate_discount.py
# import pytest
# from your_module import calculate_discount  # Reemplaza 'your_module' con el nombre real del módulo
#
# # Casos normales
# def test_calculate_discount_regular_user():
#     price = 100.0
#     discount_percent = 10.0
#     user_type = 'regular'
#     expected_result = price - (price * (discount_percent / 100))
#     assert calculate_discount(price, discount_percent, user_type) == expected_result
#
# def test_calculate_discount_premium_user():
#     price = 100.0
#     discount_percent = 10.0
#     user_type = 'premium'
#     expected_result = price - (price * ((discount_percent + 5) / 100))
#     assert calculate_discount(price, discount_percent, user_type) == expected_result
#
# # Casos edge
# def test_calculate_discount_zero_percent():
#     price = 100.0
#     discount_percent = 0.0
#     user_type = 'regular'
#     expected_result = price
#     assert calculate_discount(price, discount_percent, user_type) == expected_result
#
# def test_calculate_discount_hundred_percent():
#     price = 100.0
#     discount_percent = 100.0
#     user_type = 'regular'
#     expected_result = 0.0
#     assert calculate_discount(price, discount_percent, user_type) == expected_result
#
# def test_calculate_discount_negative_percent():
#     price = 100.0
#     discount_percent = -10.0
#     user_type = 'regular'
#     with pytest.raises(ValueError):
#         calculate_discount(price, discount_percent, user_type)
#
# # Casos de error
# def test_calculate_discount_invalid_user_type():
#     price = 100.0
#     discount_percent = 10.0
#     user_type = 'invalid'
#     with pytest.raises(ValueError):
#         calculate_discount(price, discount_percent, user_type)
#
# def test_calculate_discount_invalid_price():
#     price = -100.0
#     discount_percent = 10.0
#     user_type = 'regular'
#     with pytest.raises(ValueError):
#         calculate_discount(price, discount_percent, user_type)
#
# # Tests parametrizados
# @pytest.mark.parametrize("price, discount_percent, user_type, expected_result", [
#     (100.0, 10.0, 'regular', 90.0),
#     (100.0, 20.0, 'regular', 80.0),
#     (100.0, 10.0, 'premium', 85.0),
#     (100.0, 20.0, 'premium', 76.0),
# ])
# def test_calculate_discount_parametrized(price, discount_percent, user_type, expected_result):
#     assert calculate_discount(price, discount_percent, user_type) == expected_result
#
# # Modificar la función original para que lance excepciones en casos de error
# def calculate_discount(price, discount_percent, user_type):
#     """Calculate final price after discount.
#
#     Args:
#         price (float): Original price
#         discount_percent (float): Discount percentage (0-100)
#         user_type (str): 'premium' or 'regular'
#
#     Returns:
#         float: Final price after discount
#
#     Raises:
#         ValueError: If price, discount_percent or user_type are invalid
#     """
#     if price < 0:
#         raise ValueError("Price cannot be negative")
#     if discount_percent < 0 or discount_percent > 100:
#         raise ValueError("Discount percent must be between 0 and 100")
#     if user_type not in ['premium', 'regular']:
#         raise ValueError("Invalid user type")
#
#     if user_type == 'premium':
#         discount_percent += 5  # Extra 5% for premium users
#
#     discount_amount = price * (discount_percent / 100)
#     return price - discount_amount
# ```
#
# Para ejecutar los tests, puedes utilizar el comando `pytest` en la terminal, dentro del directorio donde se encuentra el archivo `test_calculate_discount.py`. Asegúrate de que el archivo `your_module.py` (que contiene la función `calculate_discount`) esté en el mismo directorio o en un lugar donde Python pueda importarlo.
#
# Si todo está configurado correctamente, los tests deberían ejecutarse y mostrar los resultados. Si algún test falla, pytest mostrará un mensaje de error indicando el test que falló y la razón del fallo.
#
# === ANÁLISIS DE TESTS ===
# • Métodos de test: 8
# • Assertions: 5
# • Tests parametrizados: 1
# • Cobertura estimada: Alta

# %% [markdown]
# ## Mejores Prácticas y Limitaciones
#
# ### ✅ Cuándo Usar Zero-Shot:
# - Tareas comunes y bien definidas
# - Cuando no tienes ejemplos disponibles
# - Para prototipado rápido
# - Tareas que requieren creatividad
#
# ### ❌ Cuándo NO Usar Zero-Shot:
# - Formatos de salida muy específicos
# - Tareas de dominio muy especializado
# - Cuando la consistencia es crítica
# - Tareas complejas que requieren patrones específicos
#
# ### 🎯 Mejores Prácticas:
# 1. **Sé específico**: Detalla exactamente qué quieres
# 2. **Define el formato**: Especifica cómo debe verse la salida
# 3. **Establece restricciones**: Qué debe evitar o considerar
# 4. **Usa roles**: Define quién debe "ser" el modelo
# 5. **Itera y refina**: Mejora basándote en resultados

# %%
# Ejercicio final: Diseña tu propio prompt zero-shot
def ejercicio_personalizado():
    print("=== EJERCICIO PERSONAL ===")
    print("\nDiseña un prompt zero-shot para esta tarea:")
    print("'Crear una descripción de trabajo atractiva para un puesto de desarrollador Python junior'")
    print("\nEstructura sugerida:")
    print("1. Rol/Contexto del modelo")
    print("2. Tarea específica")
    print("3. Requisitos del formato")
    print("4. Restricciones importantes")
    print("\nTu prompt aquí:")
    
    # Espacio para que el estudiante diseñe su prompt
    prompt_estudiante = """# COLOCA TU PROMPT AQUÍ
    
# Ejemplo de estructura:
# Eres un [ROL]...
# Tarea: [TAREA ESPECÍFICA]...
# Formato: [ESTRUCTURA DE SALIDA]...
# Restricciones: [LIMITACIONES]...
"""
    
    print(prompt_estudiante)
    
    # Prompt de ejemplo bien estructurado
    ejemplo_prompt = """Eres un HR Business Partner senior especializado en tecnología con 8 años de experiencia reclutando desarrolladores.
    
Tarea: Redacta una descripción de trabajo atractiva y realista para un puesto de Desarrollador Python Junior.
    
Formato requerido:
- Título del puesto
- Resumen ejecutivo (2-3 líneas)
- Responsabilidades principales (4-5 puntos)
- Requisitos técnicos (separar esenciales de deseables)
- Beneficios y cultura de empresa
- Llamada a la acción
    
Restricciones:
- Máximo 400 palabras
- Lenguaje inclusivo y accesible
- Enfócate en crecimiento profesional
- Evita jerga técnica excesiva
- Sé honesto sobre el nivel junior
    
Descripción de trabajo:"""
    
    print("\n=== EJEMPLO DE PROMPT BIEN ESTRUCTURADO ===")
    print(ejemplo_prompt)
    
    # Opcional: probar el prompt ejemplo
    print("\n¿Quieres ver el resultado del prompt ejemplo? (y/n)")
    # En un entorno real, aquí habría input del usuario
    
ejercicio_personalizado()
# Out:
# === EJERCICIO PERSONAL ===
#
# Diseña un prompt zero-shot para esta tarea:
# 'Crear una descripción de trabajo atractiva para un puesto de desarrollador Python junior'
#
# Estructura sugerida:
# 1. Rol/Contexto del modelo
# 2. Tarea específica
# 3. Requisitos del formato
# 4. Restricciones importantes
#
# Tu prompt aquí:
# # COLOCA TU PROMPT AQUÍ
#
# # Ejemplo de estructura:
# # Eres un [ROL]...
# # Tarea: [TAREA ESPECÍFICA]...
# # Formato: [ESTRUCTURA DE SALIDA]...
# # Restricciones: [LIMITACIONES]...
#
#
# === EJEMPLO DE PROMPT BIEN ESTRUCTURADO ===
# Eres un HR Business Partner senior especializado en tecnología con 8 años de experiencia reclutando desarrolladores.
#
# Tarea: Redacta una descripción de trabajo atractiva y realista para un puesto de Desarrollador Python Junior.
#
# Formato requerido:
# - Título del puesto
# - Resumen ejecutivo (2-3 líneas)
# - Responsabilidades principales (4-5 puntos)
# - Requisitos técnicos (separar esenciales de deseables)
# - Beneficios y cultura de empresa
# - Llamada a la acción
#
# Restricciones:
# - Máximo 400 palabras
# - Lenguaje inclusivo y accesible
# - Enfócate en crecimiento profesional
# - Evita jerga técnica excesiva
# - Sé honesto sobre el nivel junior
#
# Descripción de trabajo:
#
# ¿Quieres ver el resultado del prompt ejemplo? (y/n)

# %% [markdown]
# ## Conceptos Clave Aprendidos
#
# 1. **Zero-shot prompting** es efectivo para tareas comunes sin necesidad de ejemplos
# 2. **Estructura clara** del prompt mejora significativamente los resultados
# 3. **Roles específicos** generan respuestas más enfocadas y expertas
# 4. **Instrucciones graduales** ayudan con tareas complejas
# 5. **Formato definido** asegura salidas consistentes y útiles
#
# ## Próximos Pasos
#
# En el siguiente notebook exploraremos **Few-Shot Prompting**, donde aprenderemos a usar ejemplos específicos para guiar el comportamiento del modelo y lograr mayor consistencia en tareas especializadas.
#
# ### Para Practicar:
# 1. Diseña prompts zero-shot para diferentes tipos de tareas
# 2. Experimenta con diferentes roles y contextos
# 3. Compara resultados con y sin estructura específica
# 4. Mide la consistencia en múltiples ejecuciones
